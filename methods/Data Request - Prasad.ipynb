# %%
import pymongo
from pymongo import MongoClient
import time
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import csv
from sklearn import preprocessing
from nbi import *

# %%
collection = connectToNBI("bridges","mongodb://research:superSMART1%3A%3A@ist177a-mongo.ist.unomaha.edu/admin")

# %%
code_state_mapping = {'25':'MA',
                            '04':'AZ',
                            '08':'CO',
                            '38':'ND',
                            '09':'CT',
                            '19':'IA',
                            '26':'MI',
                            '48':'TX',
                            '35':'NM',
                            '17':'IL',
                            '51':'VA',
                            '23':'ME',
                            '16':'ID',
                            '36':'NY',
                            '56':'WY',
                            '29':'MO',
                            '39':'OH',
                            '28':'MS',
                            '11':'DC',
                            '21':'KY',
                            '18':'IN',
                            '06':'CA',
                            '47':'TN',
                            '12':'FL',
                            '24':'MD',
                            '34':'NJ',
                            '46':'SD',
                            '13':'GA',
                            '55':'WI',
                            '30':'MT',
                            '54':'WV',
                            '15':'HI',
                            '32':'NV',
                            '37':'NC',
                            '10':'DE',
                            '33':'NH',
                            '44':'RI',
                            '50':'VT',
                            '42':'PA',
                            '05':'AR',
                            '20':'KS',
                            '45':'SC',
                            '22':'LA',
                            '40':'OK',
                            '72':'PR',
                            '41':'OR',
                            '27':'MN',
                            '53':'WA',
                            '01':'AL',
                            '31':'NE',
                            '02':'AK',
                            '49':'UT'
                   }

# %%
# set the initials of the states
#states =  list(code_state_mapping.keys())
states = ['31']
## set the years of the states
years  =  [1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017]
## select fields for the data
fields =  {"_id":0, 
                         "year":1,           # year of the survey
                         "stateCode":1,     
                         "structureNumber":1,
                         "yearBuilt":1,
                         "deck":1,
                         "substructure":1,
                         "superstructure":1,
                         "lengthOfMaximumSpan":1,
                         "kindOfMaterial":"$structureTypeMain.kindOfMaterialDesign",
                         "Structure Type":"$structureTypeMain.typeOfDesignConstruction"
                         
         }

## database name
db = "bridges"

## Connection string
connection_string = "mongodb://research:superSMART1%3A%3A@ist177a-mongo.ist.unomaha.edu/admin"
survey_records = getSurveyRecords(states, years, fields, db, connection_string)

# %%
len(survey_records)
# Out:
# 415869

# %%
survey_records['year'].unique()
# Out:
# array([1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017])

# %%
survey_records = survey_records[['structureNumber', 'stateCode','year', 'yearBuilt', 'deck', 'lengthOfMaximumSpan','kindOfMaterial','Structure Type']]

# %%
survey_records.head()
# Out:
#   structureNumber stateCode  year  yearBuilt deck  lengthOfMaximumSpan  \
# 0      C000100405        31  1992       1925    5                  8.8
# 1      C000100305        31  1992       1935    6                  9.4
# 2     C000100505P        31  1992       1974    8                  9.4
# 3     C000100305P        31  1992       1935    7                  6.7
# 4      C000100910        31  1992       1968    7                 12.2
#
#    kindOfMaterial  Structure Type
# 0               1              11
# 1               7               2
# 2               3               2
# 3               1               1
# 4               1               1

# %%
def retMaterialNames(structure_type_coding):
    """ return kind of material name of the structure type code"""
    
    kind_of_material = {
                            1:"Concrete",
                            2:"Concrete Continuous",
                            3:"Steel",
                            4:"Steel Continuous",
                            5:"Prestressed Concrete",
                            6:"Prestressed Concrete Continuous",
                            7:"Wood or Timber",
                            8:"Masonry",
                            9:"Aluminum, Wrought Iron, or Cast Iron",
                            10:"Other",
                       }
    
    material_names = structure_type_coding.map(kind_of_material)
    
    return material_names

# %%
survey_records['Kind of Material'] = retMaterialNames(survey_records['kindOfMaterial'])

# %%
def retStructureType(structure_type_coding):
    """
      return kind of material name of the structure type code
      :return-type: List
      
    """
    
    
    structure_type = {   
                             1:"Slab",   
                             2:"Stringer/Multi-beam or Girder",
                             3:"Girder and Floorbeam System",
                             4:"Tee Beam",
                             5:"Box Beam or Girders - Multiple",
                             6:"Box Beam or Girders - Single or Spread",
                             7:"Frame (except frame culverts)",
                             8:"Orthotropic",
                             9:"Truss - Deck",
                             10:"Truss - Thru",
                             11:"Arch - Deck",
                             12:"Arch - Thru",
                             13:"Suspension",
                             14:"Stayed Girder",
                             15:"Movable - Lift",
                             16:"Movable - Bascule",
                             17:"Movable - Swing",
                             18:"Tunnel",
                             19:"Culvert (includes frame culverts)",
                             20:"Mixed types",
                             21:"Segmental Box Girder",
                             22:"Channel Beam",
                             0:"Other"
     }

    material_names = structure_type_coding.map(structure_type)
    
    return material_names

# %%
survey_records['Structure Type'] = retStructureType(survey_records['Structure Type'])

# %%
survey_records.shape
# Out:
# (415869, 9)

# %% [markdown]
# ### Data Filtering

# %% [markdown]
# ##### Bridges constructed between 1987 and 1991

# %%
#survey_records = survey_records[(survey_records['yearBuilt']>=1987) & (survey_records['yearBuilt'] <=1991)]

# %% [markdown]
# #### Test: Bridges constructed between 1987 and 1991

# %%
#survey_records.shape
# Out:
# (33163, 9)

# %%
#survey_records['yearBuilt'].unique()
# Out:
# array([1987, 1988, 1990, 1991, 1989])

# %% [markdown]
# #### Bridges with steel and girder design

# %%
# survey_records = survey_records[survey_records['Kind of Material'] == 'Steel']
# survey_records = survey_records[survey_records['Structure Type'] == 'Stringer/Multi-beam or Girder']

# %%
survey_records.shape
# Out:
# (139879, 9)

# %% [markdown]
# ##### Test Kind of Material = Steel

# %%
survey_records['Kind of Material'].unique()
# Out:
# array(['Concrete', 'Wood or Timber', 'Steel', 'Prestressed Concrete',
#        'Concrete Continuous', 'Steel Continuous',
#        'Prestressed Concrete Continuous', 'Masonry',
#        'Aluminum, Wrought Iron, or Cast Iron', nan], dtype=object)

# %% [markdown]
# #### Test: Structure Type = Stringer/Multi-beam or Girder

# %%
survey_records['Structure Type'].unique()
# Out:
# array(['Stringer/Multi-beam or Girder'], dtype=object)

# %%
survey_records.columns
# Out:
# (415869, 9)

# %% [markdown]
# ### Create Timeseries of Bridge Data

# %%
def createTimeseries(survey_records):
    """Create time series data from the loose records"""
    
    survey_timeseries = [[key]+[col for col in value] for key, value in {k:[g['stateCode'].tolist(),g['year'].tolist(),g['yearBuilt'].tolist(), g['deck'].tolist(), g['lengthOfMaximumSpan'].tolist(),g["kindOfMaterial"].tolist(),g["Kind of Material"].tolist(), g["Structure Type"].tolist()] for k, g in survey_records.groupby('structureNumber')}.items()]
    # for key, value in {k:[g['Age'].tolist(),g['ADT Type'].tolist(),g['Category'],g['superstructure'].tolist()] for k, g in survey_records.groupby('structureNumber')}.items():
    return survey_timeseries

# %%
survey_recs  = createTimeseries(survey_records)

# %%
len(survey_recs)
# Out:
# 17469

# %%
structureNumbers_NE = [i[0] for i in survey_recs]

# %%
df = pd.DataFrame({'Structure Number':structureNumbers_NE})

# %%
df.to_excel('bridges-NE.xlsx')

# %%
survey_timeseries_df = pd.DataFrame(survey_recs,  columns=['Structure Number', 'State Code', 'Year Of Survey', 'Year Built','Deck', 'Length Of Maximum Span','kindOfMaterial','StructureType','Kind of Material','Structure Type'])

# %%
survey_timeseries_df = survey_timeseries_df[['Structure Number','State Code','Year Of Survey','Year Built', 'Deck', \
                                            'Length Of Maximum Span', 'Kind of Material', 'Structure Type']]

# %%
survey_timeseries_df.shape
# Out:
# (9064, 8)

# %% [markdown]
# #### Flatten the fields

# %%
def all_the_same(elements):
    if not elements:
        return True
    return [elements[0]] * len(elements) == elements

survey_timeseries_df['No Change Span'] = [all_the_same(row) for row in survey_timeseries_df['Length Of Maximum Span']]

# %%
survey_timeseries_df['State Code'] = [ x[0] for x in survey_timeseries_df['State Code']]
survey_timeseries_df['Year Built'] = [ x[0] for x in survey_timeseries_df['Year Built']]
survey_timeseries_df['Length Of Maximum Span'] = [ x[0] for x in survey_timeseries_df['Length Of Maximum Span']]
survey_timeseries_df['Kind of Material'] = [ x[0] for x in survey_timeseries_df['Kind of Material']]
survey_timeseries_df['Structure Type'] = [ x[0] for x in survey_timeseries_df['Structure Type']]

# %% [markdown]
# ### Testing length of the span

# %%
survey_timeseries_df['No Change Span'].unique()
# Out:
# array([ True, False])

# %%
survey_timeseries_df.shape
# Out:
# (9064, 9)

# %%
final_df = survey_timeseries_df[survey_timeseries_df['No Change Span'] == True]

# %%
final_df.shape
# Out:
# (6985, 9)

# %%
final_df
# Out:
#      Structure Number State Code  \
# 0     000000000000015         51
# 1     000000000000117         51
# 2     000000000000158         51
# 4     000000000000502         26
# 6     000000000001027         35
# 7     000000000001054         37
# 8     000000000001056         42
# 9     000000000001130         37
# 10    000000000001140         37
# 11    000000000001142         37
# 15    000000000001364         37
# 16    000000000001381         26
# 17    000000000001841         42
# 18    000000000001896         42
# 19    000000000002072         26
# 20    000000000002075         51
# 21    000000000002111         05
# 22    000000000002139         51
# 23    000000000002203         42
# 24    000000000002236         42
# 25    000000000002265         26
# 26    000000000002266         26
# 27    000000000002267         26
# 28    000000000002269         51
# 29    000000000002279         26
# 30    000000000002280         26
# 31    000000000002281         26
# 32    000000000002297         26
# 33    000000000002481         51
# 34    000000000002498         51
# ...               ...        ...
# 8975     SCC 184R 092         29
# 8976     SCC 204R 092         29
# 8977     SCC 231R 092         29
# 8978     SCC 246R 092         29
# 8979     SCC 272  092         29
# 8983   SED61-6.1-47-A         08
# 8985   SLT311-10.95-A         08
# 8988  SPEC005     096         29
# 8990     TWN387002100         25
# 8991       U1425H2915         31
# 8992       U1695C6505         31
# 8993       U177525120         31
# 8994       U182503510         31
# 8995       U182504703         31
# 8996       U182522218         31
# 8997       U1825D1825         31
# 8998       U1825K2205         31
# 8999  U3875141    096         29
# 9000  W03020411DOT634         25
# 9001  W03020411MHD634         25
# 9002  W03021412DOT634         25
# 9003  W03021412MHD634         25
# 9004  W060094C5DOT634         25
# 9005  W060094C5MHD634         25
# 9006  W060154C3DOT634         25
# 9007  W060154C3MHD634         25
# 9024  WEL053.0-076.0A         08
# 9061  wel057.0-094.0a         08
# 9062  wel096.0-021.0a         08
# 9063  wel096.0-057.0a         08
#
#                                          Year Of Survey  Year Built  \
# 0                                    [1992, 1993, 2017]        1987
# 1     [2003, 2003, 2004, 2004, 2005, 2005, 2006, 200...        1988
# 2     [1992, 1993, 1994, 1995, 1996, 1997, 1998, 199...        1987
# 4            [2011, 2012, 2013, 2014, 2015, 2016, 2017]        1987
# 6                              [2009, 2010, 2011, 2012]        1987
# 7      [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999]        1989
# 8            [2011, 2012, 2013, 2014, 2015, 2016, 2017]        1987
# 9     [1992, 1992, 1993, 1993, 1994, 1994, 1995, 199...        1991
# 10    [1992, 1992, 1993, 1993, 1994, 1994, 1995, 199...        1991
# 11    [1992, 1992, 1993, 1993, 1994, 1994, 1995, 199...        1991
# 15    [1992, 1992, 1993, 1993, 1994, 1994, 1995, 199...        1991
# 16           [2011, 2012, 2013, 2014, 2015, 2016, 2017]        1988
# 17           [2011, 2012, 2013, 2014, 2015, 2016, 2017]        1987
# 18           [2011, 2012, 2013, 2014, 2015, 2016, 2017]        1991
# 19           [2011, 2012, 2013, 2014, 2015, 2016, 2017]        1987
# 20    [1992, 1993, 1994, 1995, 1996, 1997, 1998, 199...        1990
# 21    [1993, 1994, 1995, 1996, 1997, 1998, 1999, 200...        1987
# 22    [1992, 1993, 1994, 1995, 1996, 1997, 1998, 199...        1987
# 23           [2011, 2012, 2013, 2014, 2015, 2016, 2017]        1988
# 24           [2011, 2012, 2013, 2014, 2015, 2016, 2017]        1991
# 25           [2011, 2012, 2013, 2014, 2015, 2016, 2017]        1989
# 26           [2011, 2012, 2013, 2014, 2015, 2016, 2017]        1989
# 27           [2011, 2012, 2013, 2014, 2015, 2016, 2017]        1989
# 28    [1992, 1993, 1994, 1995, 1996, 1997, 1998, 199...        1987
# 29           [2011, 2012, 2013, 2014, 2015, 2016, 2017]        1989
# 30           [2011, 2012, 2013, 2014, 2015, 2016, 2017]        1989
# 31           [2011, 2012, 2013, 2014, 2015, 2016, 2017]        1989
# 32           [2011, 2012, 2013, 2014, 2015, 2016, 2017]        1989
# 33    [1993, 1994, 1995, 1996, 1997, 1998, 1999, 200...        1990
# 34    [1992, 1993, 1994, 1995, 1996, 1997, 1998, 199...        1990
# ...                                                 ...         ...
# 8975                                             [1992]        1989
# 8976                                             [1992]        1989
# 8977                                             [1992]        1989
# 8978                                             [1992]        1988
# 8979                                             [1992]        1987
# 8983   [1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000]        1991
# 8985                           [2006, 2007, 2008, 2009]        1990
# 8988                                       [1993, 1994]        1991
# 8990                           [1992, 1993, 1994, 1995]        1988
# 8991  [1993, 1994, 1995, 1996, 1997, 1998, 1999, 200...        1987
# 8992  [1992, 1993, 1994, 1995, 1996, 1997, 1998, 199...        1988
# 8993  [1992, 1992, 1992, 1992, 1993, 1993, 1993, 199...        1989
# 8994  [1992, 1993, 1994, 1995, 1996, 1997, 1998, 199...        1987
# 8995  [1992, 1993, 1994, 1995, 1996, 1997, 1998, 199...        1989
# 8996  [1997, 1998, 1999, 2000, 2001, 2002, 2003, 200...        1991
# 8997  [1992, 1993, 1994, 1995, 1996, 1997, 1998, 199...        1987
# 8998  [1992, 1992, 1993, 1993, 1994, 1994, 1995, 199...        1990
# 8999                                             [1992]        1987
# 9000   [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]        1991
# 9001  [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...        1991
# 9002   [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]        1991
# 9003  [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...        1991
# 9004   [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]        1988
# 9005  [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...        1988
# 9006   [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]        1990
# 9007  [2001, 2002, 2003, 2004, 2005, 2006, 2007, 200...        1990
# 9024  [1992, 1993, 1994, 1995, 1996, 1997, 1998, 199...        1990
# 9061                                             [2002]        1987
# 9062                                             [2002]        1991
# 9063                                             [2002]        1991
#
#                                                    Deck  \
# 0                                             [9, 9, 6]
# 1     [7, NA, 7, NA, 7, NA, 7, NA, 7, NA, 7, NA, 7, ...
# 2     [8, 8, 8, 8, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, ...
# 4                                 [7, 7, 7, 7, 7, 7, 7]
# 6                                          [7, 7, 7, 7]
# 7                              [7, 7, 7, 7, 7, 7, 7, 7]
# 8                                 [7, 7, 7, 7, 7, 7, 6]
# 9     [9, NA, 9, NA, 7, NA, 7, NA, 7, NA, 7, NA, 6, ...
# 10    [9, NA, 9, NA, 7, NA, 7, NA, 7, NA, 7, NA, 7, ...
# 11    [9, NA, 9, NA, 7, NA, 7, NA, 6, NA, 6, NA, 7, ...
# 15    [9, NA, 9, NA, 7, NA, 7, NA, 7, NA, 7, NA, 7, ...
# 16                                [6, 6, 6, 6, 6, 6, 5]
# 17                                [6, 6, 6, 6, 6, 6, 6]
# 18                                [7, 7, 7, 7, 7, 7, 7]
# 19                                [6, 6, 6, 6, 6, 6, 6]
# 20    [8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 7, 7, 7, 7, ...
# 21    [8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, ...
# 22    [8, 8, 8, 8, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, ...
# 23                                [7, 7, 7, 7, 7, 7, 7]
# 24                                [7, 7, 7, 7, 7, 7, 7]
# 25                                [6, 6, 6, 6, 6, 6, 6]
# 26                                [6, 6, 6, 6, 6, 6, 6]
# 27                                [6, 6, 6, 6, 6, 6, 6]
# 28    [8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, ...
# 29                                [6, 6, 6, 6, 6, 6, 6]
# 30                                [6, 6, 6, 6, 6, 6, 6]
# 31                                [7, 7, 7, 7, 7, 7, 7]
# 32                                [7, 7, 7, 7, 7, 7, 7]
# 33    [9, 8, 8, 8, 8, 8, 8, 7, 7, 7, 7, 7, 7, 7, 7, ...
# 34    [9, 9, 8, 8, 8, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, ...
# ...                                                 ...
# 8975                                                [9]
# 8976                                                [9]
# 8977                                                [7]
# 8978                                                [8]
# 8979                                                [9]
# 8983                           [8, 8, 8, 8, 8, 8, 8, 8]
# 8985                                       [8, 8, 7, 7]
# 8988                                             [6, 6]
# 8990                                       [9, 9, 9, 8]
# 8991  [7, 7, 7, 7, 7, 7, 7, 7, 8, 8, 8, 8, 8, 8, 8, ...
# 8992  [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, ...
# 8993  [8, NA, NA, NA, 8, NA, NA, NA, 8, NA, NA, NA, ...
# 8994       [NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA]
# 8995  [NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, N...
# 8996  [8, 8, 7, 7, 7, 7, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# 8997  [9, 7, 7, 7, 7, 7, 7, 6, 6, 6, 6, 6, 6, 6, 6, ...
# 8998  [9, NA, 7, NA, 7, NA, 7, NA, 7, NA, 7, NA, 7, ...
# 8999                                                [9]
# 9000                           [8, 8, 8, 8, 8, 8, 7, 7]
# 9001                        [8, 8, 8, 8, 8, 8, 8, 8, 8]
# 9002                           [8, 8, 8, 8, 8, 8, 8, 8]
# 9003                        [8, 8, 8, 8, 8, 8, 8, 8, 8]
# 9004                           [7, 7, 7, 7, 7, 7, 7, 7]
# 9005                        [8, 8, 8, 8, 7, 7, 7, 7, 7]
# 9006                           [8, 8, 8, 7, 7, 7, 7, 7]
# 9007                        [8, 8, 8, 8, 8, 8, 8, 8, 8]
# 9024                  [8, 8, 8, 8, 7, 7, 7, 7, 7, 7, 7]
# 9061                                                [7]
# 9062                                                [7]
# 9063                                                [7]
#
#       Length Of Maximum Span Kind of Material                 Structure Type  \
# 0                       22.3            Steel  Stringer/Multi-beam or Girder
# 1                       23.2            Steel  Stringer/Multi-beam or Girder
# 2                       18.0            Steel  Stringer/Multi-beam or Girder
# 4                       22.6            Steel  Stringer/Multi-beam or Girder
# 6                       63.4            Steel  Stringer/Multi-beam or Girder
# 7                       12.2            Steel  Stringer/Multi-beam or Girder
# 8                       36.6            Steel  Stringer/Multi-beam or Girder
# 9                       36.6            Steel  Stringer/Multi-beam or Girder
# 10                      29.3            Steel  Stringer/Multi-beam or Girder
# 11                      28.3            Steel  Stringer/Multi-beam or Girder
# 15                      29.3            Steel  Stringer/Multi-beam or Girder
# 16                       6.1            Steel  Stringer/Multi-beam or Girder
# 17                      22.6            Steel  Stringer/Multi-beam or Girder
# 18                      46.3            Steel  Stringer/Multi-beam or Girder
# 19                       9.1            Steel  Stringer/Multi-beam or Girder
# 20                      21.3            Steel  Stringer/Multi-beam or Girder
# 21                      15.2            Steel  Stringer/Multi-beam or Girder
# 22                      18.6            Steel  Stringer/Multi-beam or Girder
# 23                      53.9            Steel  Stringer/Multi-beam or Girder
# 24                       9.1            Steel  Stringer/Multi-beam or Girder
# 25                      44.8            Steel  Stringer/Multi-beam or Girder
# 26                      47.2            Steel  Stringer/Multi-beam or Girder
# 27                      47.2            Steel  Stringer/Multi-beam or Girder
# 28                      21.6            Steel  Stringer/Multi-beam or Girder
# 29                      34.4            Steel  Stringer/Multi-beam or Girder
# 30                      35.6            Steel  Stringer/Multi-beam or Girder
# 31                      33.8            Steel  Stringer/Multi-beam or Girder
# 32                      45.1            Steel  Stringer/Multi-beam or Girder
# 33                      11.9            Steel  Stringer/Multi-beam or Girder
# 34                      18.6            Steel  Stringer/Multi-beam or Girder
# ...                      ...              ...                            ...
# 8975                    15.2            Steel  Stringer/Multi-beam or Girder
# 8976                    11.6            Steel  Stringer/Multi-beam or Girder
# 8977                    18.3            Steel  Stringer/Multi-beam or Girder
# 8978                    14.3            Steel  Stringer/Multi-beam or Girder
# 8979                     6.7            Steel  Stringer/Multi-beam or Girder
# 8983                    11.6            Steel  Stringer/Multi-beam or Girder
# 8985                    11.6            Steel  Stringer/Multi-beam or Girder
# 8988                     7.6            Steel  Stringer/Multi-beam or Girder
# 8990                    22.6            Steel  Stringer/Multi-beam or Girder
# 8991                    16.8            Steel  Stringer/Multi-beam or Girder
# 8992                    38.1            Steel  Stringer/Multi-beam or Girder
# 8993                    65.5            Steel  Stringer/Multi-beam or Girder
# 8994                    26.2            Steel  Stringer/Multi-beam or Girder
# 8995                    13.1            Steel  Stringer/Multi-beam or Girder
# 8996                    28.7            Steel  Stringer/Multi-beam or Girder
# 8997                     9.4            Steel  Stringer/Multi-beam or Girder
# 8998                    67.1            Steel  Stringer/Multi-beam or Girder
# 8999                    23.5            Steel  Stringer/Multi-beam or Girder
# 9000                    19.2            Steel  Stringer/Multi-beam or Girder
# 9001                    19.2            Steel  Stringer/Multi-beam or Girder
# 9002                    20.1            Steel  Stringer/Multi-beam or Girder
# 9003                    20.1            Steel  Stringer/Multi-beam or Girder
# 9004                    23.2            Steel  Stringer/Multi-beam or Girder
# 9005                    23.2            Steel  Stringer/Multi-beam or Girder
# 9006                    13.4            Steel  Stringer/Multi-beam or Girder
# 9007                    13.4            Steel  Stringer/Multi-beam or Girder
# 9024                    10.7            Steel  Stringer/Multi-beam or Girder
# 9061                    11.6            Steel  Stringer/Multi-beam or Girder
# 9062                    11.6            Steel  Stringer/Multi-beam or Girder
# 9063                     8.5            Steel  Stringer/Multi-beam or Girder
#
#       No Change Span
# 0               True
# 1               True
# 2               True
# 4               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 15              True
# 16              True
# 17              True
# 18              True
# 19              True
# 20              True
# 21              True
# 22              True
# 23              True
# 24              True
# 25              True
# 26              True
# 27              True
# 28              True
# 29              True
# 30              True
# 31              True
# 32              True
# 33              True
# 34              True
# ...              ...
# 8975            True
# 8976            True
# 8977            True
# 8978            True
# 8979            True
# 8983            True
# 8985            True
# 8988            True
# 8990            True
# 8991            True
# 8992            True
# 8993            True
# 8994            True
# 8995            True
# 8996            True
# 8997            True
# 8998            True
# 8999            True
# 9000            True
# 9001            True
# 9002            True
# 9003            True
# 9004            True
# 9005            True
# 9006            True
# 9007            True
# 9024            True
# 9061            True
# 9062            True
# 9063            True
#
# [6985 rows x 9 columns]

# %%
final_df.to_csv('steel-girder-1987-1991-bridges-same-span.csv')
